# %%
from visual_transformer import *

# %%
device = torch.device('cuda:0') # the big machine

# %%
from game import *
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
game_settings = BIG_tool_use_advanced_2_5
game_settings.gameSize = 224 # for compatibility with brain's expected size
G = discreteGame(game_settings)

# %%
import matplotlib.pyplot as plt
plt.imshow(G.getData())

# %%
bare1_settings = G.random_bare_settings(gameSize=224, max_agent_offset=0.5)

# %%
G2 = discreteGame(bare1_settings)
plt.imshow(G2.getData())

# %%
# ok, lovely.
# hopefully my autoencoder won't randomly add new walls in the middle, lol

# %%
G2.bare_draw_arrow_at_gold()
plt.imshow(G2.getData())

# %%
# Perfect.
# May adjust it more to make a gap later, but still.
